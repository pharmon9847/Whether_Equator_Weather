# %%
import pandas as pd

# %%
cities_df = pd.read_csv("cities.csv")
cities_df.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0  komsomolskiy          75      UZ  1580076193        86  40.43
# 1           1    nanortalik         100      GL  1580076193        70  60.14
# 2           2   tuktoyaktuk          75      CA  1580076194        67  69.45
# 3           3   cape%20town          20      ZA  1580075963        72 -33.93
# 4           4      khatanga          93      RU  1580076194        98  71.97
#
#       Lng  Max Temp  Wind Speed  Feels like             Name
# 0   71.72     37.40        2.24       29.77  Yangi Marg`ilon
# 1  -45.24     22.42       14.45        8.80       Nanortalik
# 2 -133.04    -22.00        5.82      -32.28      Tuktoyaktuk
# 3   18.42     62.01        6.93       57.09        Cape Town
# 4  102.50    -21.46        1.03      -28.93         Khatanga

# %%
output_html = cities_df.to_html()
print(output_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#       <th>Feels like</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>komsomolskiy</td>
#       <td>75</td>
#       <td>UZ</td>
#       <td>1580076193</td>
#       <td>86</td>
#       <td>40.43</td>
#       <td>71.72</td>
#       <td>37.40</td>
#       <td>2.24</td>
#       <td>29.77</td>
#       <td>Yangi Marg`ilon</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>nanortalik</td>
#       <td>100</td>
#       <td>GL</td>
#       <td>1580076193</td>
#       <td>70</td>
#       <td>60.14</td>
#       <td>-45.24</td>
# ...

# %%
cities_df.to_html("output.html")
